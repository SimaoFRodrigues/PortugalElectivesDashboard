# %%
import numpy as np
import matplotlib as plt
import json

#abrir o ficheiro e dar load à data
data = []


file = "data/resultados.json"

with open (file, "r") as f:
        dataR = f.read()

with open (file, "r") as f:
        data = json.loads(dataR)

# %%
#data que podemos usar
data.keys()
# Out:
# dict_keys(['Aveiro', 'Beja', 'Braga', 'BraganÃ§a', 'Castelo Branco', 'Coimbra', 'Ã‰vora', 'Faro', 'Guarda', 'Leiria', 'Lisboa', 'Portalegre', 'Porto', 'SantarÃ©m', 'SetÃºbal', 'Viana do Castelo', 'Vila Real', 'Viseu', 'RA AÃ§ores', 'RA Madeira', 'Europa', 'Fora da Europa'])
